# %%
import pandas as pd

# %%
allergy = pd.read_excel('C:/Users/jilli/Desktop/food-allergy-analysis-Zenodo-final.xlsx')

# %%
allergy.head()
# Out:
#    SUBJECTID  BIRTHYEAR GENDERFACTOR    RACEFACTOR    ETHNICITYFACTOR  \
# 0          1       2006  S1 - Female    R1 - Black  E0 - Non-Hispanic
# 1          2       1994  S1 - Female    R0 - White  E0 - Non-Hispanic
# 2          3       2006    S0 - Male    R0 - White      E1 - Hispanic
# 3          4       2004    S0 - Male  R4 - Unknown      E1 - Hispanic
# 4          5       2006  S1 - Female    R1 - Black  E0 - Non-Hispanic
#
#          PAYERFACTOR  ATOPICMARCHCOHORT  AGESTARTYEARS  AGEENDYEARS  \
# 0      P1 - Medicaid              False       0.093087     3.164956
# 1  P0 - Non-Medicaid              False      12.232717    18.880219
# 2  P0 - Non-Medicaid               True       0.010951     6.726899
# 3  P0 - Non-Medicaid              False       2.398357     9.111567
# 4  P0 - Non-Medicaid              False       0.013689     6.193018
#
#    SHELLFISHALGSTART  ...  CASHEWALGEND  ATOPICDERMSTART  ATOPICDERMEND  \
# 0                NaN  ...           NaN              NaN            NaN
# 1                NaN  ...           NaN              NaN            NaN
# 2                NaN  ...           NaN         4.884326            NaN
# 3                NaN  ...           NaN              NaN            NaN
# 4                NaN  ...           NaN              NaN            NaN
#
#    ALLERGICRHINITISSTART  ALLERGICRHINITISEND  ASTHMASTART  ASTHMAEND  \
# 0                    NaN                  NaN          NaN        NaN
# 1                    NaN                  NaN          NaN        NaN
# 2               3.917864             6.157426     5.127995        NaN
# 3                    NaN                  NaN          NaN        NaN
# 4                    NaN                  NaN          NaN        NaN
#
#    FIRSTASTHMARX  LASTASTHMARX  NUMASTHMARX
# 0            NaN           NaN          NaN
# 1      12.262834     18.880219          2.0
# 2       1.404517      6.157426          4.0
# 3            NaN           NaN          NaN
# 4            NaN           NaN          NaN
#
# [5 rows x 50 columns]

# %%
#Viewing RACEFACTOR value counts

# %%
allergy['RACEFACTOR'].value_counts()
# Out:
# R0 - White                        183308
# R1 - Black                         97795
# R4 - Unknown                       40940
# R2 - Asian or Pacific Islander      9152
# R3 - Other                          2005
# Name: RACEFACTOR, dtype: int64

# %%
#Will use 0 for White, 1 for Black, 2 for Asian or Pacific Islander, 3 for Other, 4 for Unknown.

# %%
def RACEFACTOR_recode (series):
    if series == "R0 - White":
        return 0
    if series == "R1 - Black":
        return 1
    if series == "R2 - Asian or Pacific Islander":
        return 2
    if series == "R3 - Other":
        return 3
    if series == "R4 - Unknown":
        return 4

# %%
allergy['RACEFACTOR']=allergy['RACEFACTOR'].apply(RACEFACTOR_recode)

# %%
allergy.head()
# Out:
#    SUBJECTID  BIRTHYEAR GENDERFACTOR  RACEFACTOR    ETHNICITYFACTOR  \
# 0          1       2006  S1 - Female           1  E0 - Non-Hispanic
# 1          2       1994  S1 - Female           0  E0 - Non-Hispanic
# 2          3       2006    S0 - Male           0      E1 - Hispanic
# 3          4       2004    S0 - Male           4      E1 - Hispanic
# 4          5       2006  S1 - Female           1  E0 - Non-Hispanic
#
#          PAYERFACTOR  ATOPICMARCHCOHORT  AGESTARTYEARS  AGEENDYEARS  \
# 0      P1 - Medicaid              False       0.093087     3.164956
# 1  P0 - Non-Medicaid              False      12.232717    18.880219
# 2  P0 - Non-Medicaid               True       0.010951     6.726899
# 3  P0 - Non-Medicaid              False       2.398357     9.111567
# 4  P0 - Non-Medicaid              False       0.013689     6.193018
#
#    SHELLFISHALGSTART  ...  CASHEWALGEND  ATOPICDERMSTART  ATOPICDERMEND  \
# 0                NaN  ...           NaN              NaN            NaN
# 1                NaN  ...           NaN              NaN            NaN
# 2                NaN  ...           NaN         4.884326            NaN
# 3                NaN  ...           NaN              NaN            NaN
# 4                NaN  ...           NaN              NaN            NaN
#
#    ALLERGICRHINITISSTART  ALLERGICRHINITISEND  ASTHMASTART  ASTHMAEND  \
# 0                    NaN                  NaN          NaN        NaN
# 1                    NaN                  NaN          NaN        NaN
# 2               3.917864             6.157426     5.127995        NaN
# 3                    NaN                  NaN          NaN        NaN
# 4                    NaN                  NaN          NaN        NaN
#
#    FIRSTASTHMARX  LASTASTHMARX  NUMASTHMARX
# 0            NaN           NaN          NaN
# 1      12.262834     18.880219          2.0
# 2       1.404517      6.157426          4.0
# 3            NaN           NaN          NaN
# 4            NaN           NaN          NaN
#
# [5 rows x 50 columns]

# %%
#Success. Now onto GENDERFACTOR

# %%
allergy['GENDERFACTOR'].value_counts()
# Out:
# S0 - Male      169032
# S1 - Female    164168
# Name: GENDERFACTOR, dtype: int64

# %%
#Will use 0 for Male, 1 for Female.

# %%
def GENDERFACTOR_recode (series):
    if series == "S0 - Male":
        return 0
    if series == "S1 - Female":
        return 1

# %%
allergy['GENDERFACTOR']=allergy['GENDERFACTOR'].apply(GENDERFACTOR_recode)

# %%
allergy.head()
# Out:
#    SUBJECTID  BIRTHYEAR  GENDERFACTOR  RACEFACTOR    ETHNICITYFACTOR  \
# 0          1       2006             1           1  E0 - Non-Hispanic
# 1          2       1994             1           0  E0 - Non-Hispanic
# 2          3       2006             0           0      E1 - Hispanic
# 3          4       2004             0           4      E1 - Hispanic
# 4          5       2006             1           1  E0 - Non-Hispanic
#
#          PAYERFACTOR  ATOPICMARCHCOHORT  AGESTARTYEARS  AGEENDYEARS  \
# 0      P1 - Medicaid              False       0.093087     3.164956
# 1  P0 - Non-Medicaid              False      12.232717    18.880219
# 2  P0 - Non-Medicaid               True       0.010951     6.726899
# 3  P0 - Non-Medicaid              False       2.398357     9.111567
# 4  P0 - Non-Medicaid              False       0.013689     6.193018
#
#    SHELLFISHALGSTART  ...  CASHEWALGEND  ATOPICDERMSTART  ATOPICDERMEND  \
# 0                NaN  ...           NaN              NaN            NaN
# 1                NaN  ...           NaN              NaN            NaN
# 2                NaN  ...           NaN         4.884326            NaN
# 3                NaN  ...           NaN              NaN            NaN
# 4                NaN  ...           NaN              NaN            NaN
#
#    ALLERGICRHINITISSTART  ALLERGICRHINITISEND  ASTHMASTART  ASTHMAEND  \
# 0                    NaN                  NaN          NaN        NaN
# 1                    NaN                  NaN          NaN        NaN
# 2               3.917864             6.157426     5.127995        NaN
# 3                    NaN                  NaN          NaN        NaN
# 4                    NaN                  NaN          NaN        NaN
#
#    FIRSTASTHMARX  LASTASTHMARX  NUMASTHMARX
# 0            NaN           NaN          NaN
# 1      12.262834     18.880219          2.0
# 2       1.404517      6.157426          4.0
# 3            NaN           NaN          NaN
# 4            NaN           NaN          NaN
#
# [5 rows x 50 columns]

# %%
#Done. Now onto ETHNICITYFACTOR.

# %%
allergy['ETHNICITYFACTOR'].value_counts()
# Out:
# E0 - Non-Hispanic    317868
# E1 - Hispanic         15332
# Name: ETHNICITYFACTOR, dtype: int64

# %%
#Will use 0 for Non-Hispanic, 1 for Hispanic.

# %%
def ETHNICITYFACTOR_recode (series):
    if series == "E0 - Non-Hispanic":
        return 0
    if series == "E1 - Hispanic":
        return 1

# %%
allergy['ETHNICITYFACTOR']=allergy['ETHNICITYFACTOR'].apply(ETHNICITYFACTOR_recode)

# %%
allergy.head()
# Out:
#    SUBJECTID  BIRTHYEAR  GENDERFACTOR  RACEFACTOR  ETHNICITYFACTOR  \
# 0          1       2006             1           1                0
# 1          2       1994             1           0                0
# 2          3       2006             0           0                1
# 3          4       2004             0           4                1
# 4          5       2006             1           1                0
#
#          PAYERFACTOR  ATOPICMARCHCOHORT  AGESTARTYEARS  AGEENDYEARS  \
# 0      P1 - Medicaid              False       0.093087     3.164956
# 1  P0 - Non-Medicaid              False      12.232717    18.880219
# 2  P0 - Non-Medicaid               True       0.010951     6.726899
# 3  P0 - Non-Medicaid              False       2.398357     9.111567
# 4  P0 - Non-Medicaid              False       0.013689     6.193018
#
#    SHELLFISHALGSTART  ...  CASHEWALGEND  ATOPICDERMSTART  ATOPICDERMEND  \
# 0                NaN  ...           NaN              NaN            NaN
# 1                NaN  ...           NaN              NaN            NaN
# 2                NaN  ...           NaN         4.884326            NaN
# 3                NaN  ...           NaN              NaN            NaN
# 4                NaN  ...           NaN              NaN            NaN
#
#    ALLERGICRHINITISSTART  ALLERGICRHINITISEND  ASTHMASTART  ASTHMAEND  \
# 0                    NaN                  NaN          NaN        NaN
# 1                    NaN                  NaN          NaN        NaN
# 2               3.917864             6.157426     5.127995        NaN
# 3                    NaN                  NaN          NaN        NaN
# 4                    NaN                  NaN          NaN        NaN
#
#    FIRSTASTHMARX  LASTASTHMARX  NUMASTHMARX
# 0            NaN           NaN          NaN
# 1      12.262834     18.880219          2.0
# 2       1.404517      6.157426          4.0
# 3            NaN           NaN          NaN
# 4            NaN           NaN          NaN
#
# [5 rows x 50 columns]

# %%
#Now to drop PAYERFACTOR

# %%
allergy.drop(['PAYERFACTOR'], axis=1)
# Out:
#         SUBJECTID  BIRTHYEAR  GENDERFACTOR  RACEFACTOR  ETHNICITYFACTOR  \
# 0               1       2006             1           1                0
# 1               2       1994             1           0                0
# 2               3       2006             0           0                1
# 3               4       2004             0           4                1
# 4               5       2006             1           1                0
# ...           ...        ...           ...         ...              ...
# 333195     333196       2006             0           0                0
# 333196     333197       2006             1           1                0
# 333197     333198       2006             0           0                0
# 333198     333199       2006             0           3                0
# 333199     333200       2006             1           0                0
#
#         ATOPICMARCHCOHORT  AGESTARTYEARS  AGEENDYEARS  SHELLFISHALGSTART  \
# 0                   False       0.093087     3.164956                NaN
# 1                   False      12.232717    18.880219                NaN
# 2                    True       0.010951     6.726899                NaN
# 3                   False       2.398357     9.111567                NaN
# 4                   False       0.013689     6.193018                NaN
# ...                   ...            ...          ...                ...
# 333195              False       0.736482     7.449692                NaN
# 333196               True       0.019165     6.984257                NaN
# 333197              False       0.443532     7.405886                NaN
# 333198               True       0.013689     7.017112                NaN
# 333199              False       0.019165     3.014374                NaN
#
#         SHELLFISHALGEND  ...  CASHEWALGEND  ATOPICDERMSTART  ATOPICDERMEND  \
# 0                   NaN  ...           NaN              NaN            NaN
# 1                   NaN  ...           NaN              NaN            NaN
# 2                   NaN  ...           NaN         4.884326            NaN
# 3                   NaN  ...           NaN              NaN            NaN
# 4                   NaN  ...           NaN              NaN            NaN
# ...                 ...  ...           ...              ...            ...
# 333195              NaN  ...           NaN         0.736482            NaN
# 333196              NaN  ...           NaN              NaN            NaN
# 333197              NaN  ...           NaN              NaN            NaN
# 333198              NaN  ...           NaN              NaN            NaN
# 333199              NaN  ...           NaN         0.347707       0.347707
#
#         ALLERGICRHINITISSTART  ALLERGICRHINITISEND  ASTHMASTART  ASTHMAEND  \
# 0                         NaN                  NaN          NaN        NaN
# 1                         NaN                  NaN          NaN        NaN
# 2                    3.917864             6.157426     5.127995        NaN
# 3                         NaN                  NaN          NaN        NaN
# 4                         NaN                  NaN          NaN        NaN
# ...                       ...                  ...          ...        ...
# 333195                    NaN                  NaN     5.426420   7.449692
# 333196                    NaN                  NaN          NaN        NaN
# 333197                    NaN                  NaN     2.321697        NaN
# 333198                    NaN                  NaN          NaN        NaN
# 333199                    NaN                  NaN          NaN        NaN
#
#         FIRSTASTHMARX  LASTASTHMARX  NUMASTHMARX
# 0                 NaN           NaN          NaN
# 1           12.262834     18.880219          2.0
# 2            1.404517      6.157426          4.0
# 3                 NaN           NaN          NaN
# 4                 NaN           NaN          NaN
# ...               ...           ...          ...
# 333195            NaN           NaN          NaN
# 333196            NaN           NaN          NaN
# 333197       2.321697      6.650240          4.0
# 333198            NaN           NaN          NaN
# 333199            NaN           NaN          NaN
#
# [333200 rows x 49 columns]

# %%
allergy.drop(['PAYERFACTOR', 'ATOPICMARCHCOHORT'], axis=1)
# Out:
#         SUBJECTID  BIRTHYEAR  GENDERFACTOR  RACEFACTOR  ETHNICITYFACTOR  \
# 0               1       2006             1           1                0
# 1               2       1994             1           0                0
# 2               3       2006             0           0                1
# 3               4       2004             0           4                1
# 4               5       2006             1           1                0
# ...           ...        ...           ...         ...              ...
# 333195     333196       2006             0           0                0
# 333196     333197       2006             1           1                0
# 333197     333198       2006             0           0                0
# 333198     333199       2006             0           3                0
# 333199     333200       2006             1           0                0
#
#         AGESTARTYEARS  AGEENDYEARS  SHELLFISHALGSTART  SHELLFISHALGEND  \
# 0            0.093087     3.164956                NaN              NaN
# 1           12.232717    18.880219                NaN              NaN
# 2            0.010951     6.726899                NaN              NaN
# 3            2.398357     9.111567                NaN              NaN
# 4            0.013689     6.193018                NaN              NaN
# ...               ...          ...                ...              ...
# 333195       0.736482     7.449692                NaN              NaN
# 333196       0.019165     6.984257                NaN              NaN
# 333197       0.443532     7.405886                NaN              NaN
# 333198       0.013689     7.017112                NaN              NaN
# 333199       0.019165     3.014374                NaN              NaN
#
#         FISHALGSTART  ...  CASHEWALGEND  ATOPICDERMSTART  ATOPICDERMEND  \
# 0                NaN  ...           NaN              NaN            NaN
# 1                NaN  ...           NaN              NaN            NaN
# 2                NaN  ...           NaN         4.884326            NaN
# 3                NaN  ...           NaN              NaN            NaN
# 4                NaN  ...           NaN              NaN            NaN
# ...              ...  ...           ...              ...            ...
# 333195           NaN  ...           NaN         0.736482            NaN
# 333196           NaN  ...           NaN              NaN            NaN
# 333197           NaN  ...           NaN              NaN            NaN
# 333198           NaN  ...           NaN              NaN            NaN
# 333199           NaN  ...           NaN         0.347707       0.347707
#
#         ALLERGICRHINITISSTART  ALLERGICRHINITISEND  ASTHMASTART  ASTHMAEND  \
# 0                         NaN                  NaN          NaN        NaN
# 1                         NaN                  NaN          NaN        NaN
# 2                    3.917864             6.157426     5.127995        NaN
# 3                         NaN                  NaN          NaN        NaN
# 4                         NaN                  NaN          NaN        NaN
# ...                       ...                  ...          ...        ...
# 333195                    NaN                  NaN     5.426420   7.449692
# 333196                    NaN                  NaN          NaN        NaN
# 333197                    NaN                  NaN     2.321697        NaN
# 333198                    NaN                  NaN          NaN        NaN
# 333199                    NaN                  NaN          NaN        NaN
#
#         FIRSTASTHMARX  LASTASTHMARX  NUMASTHMARX
# 0                 NaN           NaN          NaN
# 1           12.262834     18.880219          2.0
# 2            1.404517      6.157426          4.0
# 3                 NaN           NaN          NaN
# 4                 NaN           NaN          NaN
# ...               ...           ...          ...
# 333195            NaN           NaN          NaN
# 333196            NaN           NaN          NaN
# 333197       2.321697      6.650240          4.0
# 333198            NaN           NaN          NaN
# 333199            NaN           NaN          NaN
#
# [333200 rows x 48 columns]

# %%
allergy.fillna(0)
# Out:
#         SUBJECTID  BIRTHYEAR  GENDERFACTOR  RACEFACTOR  ETHNICITYFACTOR  \
# 0               1       2006             1           1                0
# 1               2       1994             1           0                0
# 2               3       2006             0           0                1
# 3               4       2004             0           4                1
# 4               5       2006             1           1                0
# ...           ...        ...           ...         ...              ...
# 333195     333196       2006             0           0                0
# 333196     333197       2006             1           1                0
# 333197     333198       2006             0           0                0
# 333198     333199       2006             0           3                0
# 333199     333200       2006             1           0                0
#
#               PAYERFACTOR  ATOPICMARCHCOHORT  AGESTARTYEARS  AGEENDYEARS  \
# 0           P1 - Medicaid              False       0.093087     3.164956
# 1       P0 - Non-Medicaid              False      12.232717    18.880219
# 2       P0 - Non-Medicaid               True       0.010951     6.726899
# 3       P0 - Non-Medicaid              False       2.398357     9.111567
# 4       P0 - Non-Medicaid              False       0.013689     6.193018
# ...                   ...                ...            ...          ...
# 333195  P0 - Non-Medicaid              False       0.736482     7.449692
# 333196      P1 - Medicaid               True       0.019165     6.984257
# 333197  P0 - Non-Medicaid              False       0.443532     7.405886
# 333198  P0 - Non-Medicaid               True       0.013689     7.017112
# 333199  P0 - Non-Medicaid              False       0.019165     3.014374
#
#         SHELLFISHALGSTART  ...  CASHEWALGEND  ATOPICDERMSTART  ATOPICDERMEND  \
# 0                     0.0  ...           0.0         0.000000       0.000000
# 1                     0.0  ...           0.0         0.000000       0.000000
# 2                     0.0  ...           0.0         4.884326       0.000000
# 3                     0.0  ...           0.0         0.000000       0.000000
# 4                     0.0  ...           0.0         0.000000       0.000000
# ...                   ...  ...           ...              ...            ...
# 333195                0.0  ...           0.0         0.736482       0.000000
# 333196                0.0  ...           0.0         0.000000       0.000000
# 333197                0.0  ...           0.0         0.000000       0.000000
# 333198                0.0  ...           0.0         0.000000       0.000000
# 333199                0.0  ...           0.0         0.347707       0.347707
#
#         ALLERGICRHINITISSTART  ALLERGICRHINITISEND  ASTHMASTART  ASTHMAEND  \
# 0                    0.000000             0.000000     0.000000   0.000000
# 1                    0.000000             0.000000     0.000000   0.000000
# 2                    3.917864             6.157426     5.127995   0.000000
# 3                    0.000000             0.000000     0.000000   0.000000
# 4                    0.000000             0.000000     0.000000   0.000000
# ...                       ...                  ...          ...        ...
# 333195               0.000000             0.000000     5.426420   7.449692
# 333196               0.000000             0.000000     0.000000   0.000000
# 333197               0.000000             0.000000     2.321697   0.000000
# 333198               0.000000             0.000000     0.000000   0.000000
# 333199               0.000000             0.000000     0.000000   0.000000
#
#         FIRSTASTHMARX  LASTASTHMARX  NUMASTHMARX
# 0            0.000000      0.000000          0.0
# 1           12.262834     18.880219          2.0
# 2            1.404517      6.157426          4.0
# 3            0.000000      0.000000          0.0
# 4            0.000000      0.000000          0.0
# ...               ...           ...          ...
# 333195       0.000000      0.000000          0.0
# 333196       0.000000      0.000000          0.0
# 333197       2.321697      6.650240          4.0
# 333198       0.000000      0.000000          0.0
# 333199       0.000000      0.000000          0.0
#
# [333200 rows x 50 columns]

# %%
allergy.drop(['PAYERFACTOR', 'ATOPICMARCHCOHORT'], axis=1)
# Out:
#         SUBJECTID  BIRTHYEAR  GENDERFACTOR  RACEFACTOR  ETHNICITYFACTOR  \
# 0               1       2006             1           1                0
# 1               2       1994             1           0                0
# 2               3       2006             0           0                1
# 3               4       2004             0           4                1
# 4               5       2006             1           1                0
# ...           ...        ...           ...         ...              ...
# 333195     333196       2006             0           0                0
# 333196     333197       2006             1           1                0
# 333197     333198       2006             0           0                0
# 333198     333199       2006             0           3                0
# 333199     333200       2006             1           0                0
#
#         AGESTARTYEARS  AGEENDYEARS  SHELLFISHALGSTART  SHELLFISHALGEND  \
# 0            0.093087     3.164956                NaN              NaN
# 1           12.232717    18.880219                NaN              NaN
# 2            0.010951     6.726899                NaN              NaN
# 3            2.398357     9.111567                NaN              NaN
# 4            0.013689     6.193018                NaN              NaN
# ...               ...          ...                ...              ...
# 333195       0.736482     7.449692                NaN              NaN
# 333196       0.019165     6.984257                NaN              NaN
# 333197       0.443532     7.405886                NaN              NaN
# 333198       0.013689     7.017112                NaN              NaN
# 333199       0.019165     3.014374                NaN              NaN
#
#         FISHALGSTART  ...  CASHEWALGEND  ATOPICDERMSTART  ATOPICDERMEND  \
# 0                NaN  ...           NaN              NaN            NaN
# 1                NaN  ...           NaN              NaN            NaN
# 2                NaN  ...           NaN         4.884326            NaN
# 3                NaN  ...           NaN              NaN            NaN
# 4                NaN  ...           NaN              NaN            NaN
# ...              ...  ...           ...              ...            ...
# 333195           NaN  ...           NaN         0.736482            NaN
# 333196           NaN  ...           NaN              NaN            NaN
# 333197           NaN  ...           NaN              NaN            NaN
# 333198           NaN  ...           NaN              NaN            NaN
# 333199           NaN  ...           NaN         0.347707       0.347707
#
#         ALLERGICRHINITISSTART  ALLERGICRHINITISEND  ASTHMASTART  ASTHMAEND  \
# 0                         NaN                  NaN          NaN        NaN
# 1                         NaN                  NaN          NaN        NaN
# 2                    3.917864             6.157426     5.127995        NaN
# 3                         NaN                  NaN          NaN        NaN
# 4                         NaN                  NaN          NaN        NaN
# ...                       ...                  ...          ...        ...
# 333195                    NaN                  NaN     5.426420   7.449692
# 333196                    NaN                  NaN          NaN        NaN
# 333197                    NaN                  NaN     2.321697        NaN
# 333198                    NaN                  NaN          NaN        NaN
# 333199                    NaN                  NaN          NaN        NaN
#
#         FIRSTASTHMARX  LASTASTHMARX  NUMASTHMARX
# 0                 NaN           NaN          NaN
# 1           12.262834     18.880219          2.0
# 2            1.404517      6.157426          4.0
# 3                 NaN           NaN          NaN
# 4                 NaN           NaN          NaN
# ...               ...           ...          ...
# 333195            NaN           NaN          NaN
# 333196            NaN           NaN          NaN
# 333197       2.321697      6.650240          4.0
# 333198            NaN           NaN          NaN
# 333199            NaN           NaN          NaN
#
# [333200 rows x 48 columns]

# %%
#recode age into months / years

# %%
allergy.AGESTARTYEARS.value_counts()
# Out:
#  0.010951     18201
#  0.013689     17773
#  0.016427     16645
#  0.019165     15020
#  0.008214      8735
#               ...
#  17.180014        1
# -0.095825         1
# -0.235455         1
#  17.341547        1
#  17.524983        1
# Name: AGESTARTYEARS, Length: 6480, dtype: int64

# %%
import numpy as np

# %%
allergy.AGESTARTYEARS.describe()
# Out:
# count    333200.000000
# mean          3.942140
# std           4.646174
# min          -4.312115
# 25%           0.021903
# 50%           1.763176
# 75%           7.208761
# max          17.984942
# Name: AGESTARTYEARS, dtype: float64

# %%
import pandas as pd

# %%
allergy.loc[:,"AGESTARTYEARS"]
# Out:
# 0          0.093087
# 1         12.232717
# 2          0.010951
# 3          2.398357
# 4          0.013689
#             ...
# 333195     0.736482
# 333196     0.019165
# 333197     0.443532
# 333198     0.013689
# 333199     0.019165
# Name: AGESTARTYEARS, Length: 333200, dtype: float64

# %%
data = allergy.loc[:,"AGESTARTYEARS"]

# %%
allergy = pd.DataFrame(data, columns=['AGESTARTYEARS'])

# %%
allergy
# Out:
#         AGESTARTYEARS
# 0            0.093087
# 1           12.232717
# 2            0.010951
# 3            2.398357
# 4            0.013689
# ...               ...
# 333195       0.736482
# 333196       0.019165
# 333197       0.443532
# 333198       0.013689
# 333199       0.019165
#
# [333200 rows x 1 columns]

# %%
###we need to somehow use the function below for only numbers <1

# %%
allergy
# Out:
#         AGESTARTYEARS
# 0            0.093087
# 1           12.232717
# 2            0.010951
# 3            2.398357
# 4            0.013689
# ...               ...
# 333195       0.736482
# 333196       0.019165
# 333197       0.443532
# 333198       0.013689
# 333199       0.019165
#
# [333200 rows x 1 columns]

# %%
allergy['AgeMonths'] = allergy.apply(lambda row: (row.AGESTARTYEARS * 12) - row.AGESTARTYEARS, axis = 1)

# %%
print(allergy)
# Out:
#         AGESTARTYEARS   AgeMonths
# 0            0.093087    1.023956
# 1           12.232717  134.559891
# 2            0.010951    0.120465
# 3            2.398357   26.381930
# 4            0.013689    0.150582
# ...               ...         ...
# 333195       0.736482    8.101300
# 333196       0.019165    0.210815
# 333197       0.443532    4.878850
# 333198       0.013689    0.150582
# 333199       0.019165    0.210815
#
# [333200 rows x 2 columns]

# %%
def Age (series):
    if series <= 2:
        return  "2"
    if series <= 4:
        return "4"
    if series <= 6:
        return "6"
    if series <= 10:
        return "10"
    else:
        return "11 - 17"
    
allergy["StartAge"] = allergy['AGESTARTYEARS'].apply(Age)

# %%
allergy["StartAge"].value_counts()
# Out:
# 2          170240
# 10          49896
# 11 - 17     49809
# 4           33216
# 6           30039
# Name: StartAge, dtype: int64
